# %% [markdown]
# ### Project_1_벚꽃 해시태그 활용
#
# 위치데이터를 가져와 지도에 표시
#
# 핫플레이스 찾기
#
# 인스타 광고제거방법: 아이디당 같은해시태그 게시물 10개넘어갈시 drop
#
# 상관계수 히트맵은 어디에 적용하는게 좋을까

# %%
import bs4
import requests as rq
import pandas as pd
import json
import googlemaps
from selenium import webdriver
import datetime
import urllib
import numpy as np
import folium
import datetime as dt
import re

# %%
parsed=urllib.parse.quote("벚꽃")
my_url = 'https://www.instagram.com/explore/tags/'+str(parsed)+'/?__a=1'
my_headers={'User-Agent': 'Mozilla/5.0',
           'cookie':'mid=YGvmmwAEAAF9Fgy3TOuIb7BYCtjQ; ig_did=787B9559-BD80-43F9-8556-8E2834485164; ig_nrcb=1; fbm_124024574287414=base_domain=.instagram.com; csrftoken=PMKYZhUwZsPPghlaP0bvjx7l0KTwJ2Nx; ds_user_id=47307588687; rur=FTW; fbsr_124024574287414=dk2hYFpULiW-AkOWKdnb_xENp0nrNq0IU_kXB8o0zWs....; sessionid=47307588687:P22Y3hm0VfYLbt:25'
            ,'referer':'https://www.instagram.com/explore/tags/'+str(parsed)+'/'}
res1 = rq.get(url = my_url,headers=my_headers)
max_id=json.loads(res1.text)['data']['recent']['next_max_id']

#cookie외 headers 데이터값은 로그인시 생성되는 데이터라서 수정필요
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-061fff30089c> in <module>
#       5             ,'referer':'https://www.instagram.com/explore/tags/'+str(parsed)+'/'}
#       6 res1 = rq.get(url = my_url,headers=my_headers)
# ----> 7 max_id=json.loads(res1.text)['data']['recent']['next_max_id']
#       8
#       9 #cookie외 headers 데이터값은 로그인시 생성되는 데이터라서 수정필요
#
# KeyError: 'data'

# %%
my_url = 'https://i.instagram.com/api/v1/tags/'+str(parsed)+'/sections/'
count=0
loca_table=[]
for i in range(1,1000):
    p={'include_persistent': 0,
        'max_id': max_id,
        'page': i,
        'surface': 'grid',
        'tab': 'recent'}
    my_headers={'User-Agent': 'Mozilla/5.0',
               'cookie':'mid=YGvmmwAEAAF9Fgy3TOuIb7BYCtjQ; ig_did=787B9559-BD80-43F9-8556-8E2834485164; ig_nrcb=1; fbm_124024574287414=base_domain=.instagram.com; csrftoken=PMKYZhUwZsPPghlaP0bvjx7l0KTwJ2Nx; ds_user_id=47307588687; rur=FTW; fbsr_124024574287414=dk2hYFpULiW-AkOWKdnb_xENp0nrNq0IU_kXB8o0zWs....; sessionid=47307588687:P22Y3hm0VfYLbt:25',
                'referer':'https://www.instagram.com/',
               'x-csrftoken': 'PMKYZhUwZsPPghlaP0bvjx7l0KTwJ2Nx',
                'x-ig-app-id': '936619743392459',
                'x-ig-www-claim': 'hmac.AR2kevD0lVdDwHFMjKoVqT_7totcP-ESm9-BnVfy9VX3ECCe',
                'x-instagram-ajax': '6bf090d32915'}
    res = rq.post(url = my_url,headers=my_headers,data=p)
    sections=json.loads(res.text)['sections']
    max_id=str(json.loads(res.text)['next_max_id'])
    if i>100 and res.status_code>=200:
        for s in sections:
            count+=1
            medias=s['layout_content']['medias']
            for m in medias:
    #             print(count,m)

                if ('location' in m['media'])and('lat' in m['media']['location']):
                    if 'carousel_media_count' in m['media']:

                        if m['media']['carousel_media'][0]['media_type']==1:
                            image=m['media']['carousel_media'][0]['image_versions2']['candidates'][9]['url']
                        else: image=''
                    else:
                        image=m['media']['image_versions2']['candidates'][9]['url']

                    if 'comments_disabled' not in m['media']:
                        comments=m['media']['comment_count']
                    else: comments=''

                    if m['media']['caption']!=None: hashtag=m['media']['caption']['text']
                    else: hashtag=''
                    hashtag=[re.findall(r'#[^\s#,\\]+', hashtag)]

                    time=dt.datetime.fromtimestamp(m['media']['taken_at']).strftime('%Y-%m-%d')
                    code=m['media']['code']
                    loca_name=m['media']['location']['name']
                    likes=m['media']['like_count']
                    lat=m['media']['location']['lat']
                    lng=m['media']['location']['lng']
                    loca=[count,time,loca_name,lat,lng,likes,comments,hashtag,image,code]
                    loca_table.append(loca)
                
df2=pd.DataFrame(loca_table,columns=['num','time','name','latitude','longitude','likes','comments','hashtag','image','code'])
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a6a001716363> in <module>
# ----> 1 my_url = 'https://i.instagram.com/api/v1/tags/'+str(parsed)+'/sections/'
#       2 count=0
#       3 loca_table=[]
#       4 for i in range(1,1000):
#       5     p={'include_persistent': 0,
#
# NameError: name 'parsed' is not defined

# %%
df3=df2.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-82eebe79d547> in <module>
# ----> 1 df3=df2.copy()
#
# NameError: name 'df2' is not defined

# %%
df3.sort_values(by='time',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8ed0262bb62c> in <module>
# ----> 1 df3.sort_values(by='time',ascending=False)
#
# NameError: name 'df3' is not defined

# %%
df3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3357e37d2add> in <module>
# ----> 1 df3
#
# NameError: name 'df3' is not defined

# %%
df2.to_csv('project1_df2.csv',encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-58a3da7e075b> in <module>
# ----> 1 df2.to_csv('project1_df2.csv',encoding='utf-8')
#
# NameError: name 'df2' is not defined

# %%
pd.read

# %%
df2.sort_values(by='likes',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e343094ef95f> in <module>
# ----> 1 df2.sort_values(by='likes',ascending=False)
#
# NameError: name 'df2' is not defined

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2068723f1203> in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
df.drop('address',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-052a60507507> in <module>
# ----> 1 df.drop('address',axis=1,inplace=True)
#
# NameError: name 'df' is not defined

# %%
df.to_csv('project1.csv',encoding='utf-8')

# %%
df=pd.read_csv('project1.csv',encoding='utf-8',index_col=0)

# %%
df
# Out:
#      num                     name   latitude   longitude
# 0      1                      경주시  35.855835  129.222778
# 1      1                     동네공원  37.515020  127.016480
# 2      3          Gyeongju, Korea  35.842800  129.212000
# 3      5               한국경마축산고등학교  35.441353  127.514898
# 4      5                 잠실여자고등학교  37.502157  127.113131
# ..   ...                      ...        ...         ...
# 940  982                      안양천  37.517625  126.880346
# 941  982                   철산동어딘가  37.474937  126.868053
# 942  982  Namsangol Hanok Village  37.559167  126.993889
# 943  983             Seoul, Korea  37.515020  127.016480
# 944  983                   백암고등학교  37.510615  126.843138
#
# [945 rows x 4 columns]

# %%
df['address']=np.nan

# %%
for i in range(len(df)):
    lat=df.loc[i,'latitude']
    lng=df.loc[i,'longitude']
    url = 'https://dapi.kakao.com/v2/local/geo/coord2address.json?x='+str(lng)+'&y='+str(lat)

    headers = {
        "Authorization": "KakaoAK d8ccb9b8ca357957a3ab40332f9020f0"     
        # 입력시 반드시  KakaoAK 뒤에 한 칸 띄우고 API키 값을 적어야 합니다. 
    }
#     print(i)
    places = rq.get(url, headers = headers).json()['documents']#[0]#['address']['address_name']
    if places!=[]:
        df.loc[i,'address']=places[0]['address']['address_name']
    #if places[]

# %%
df.dropna(axis=0,inplace=True)

# %%
df
# Out:
#      num                            name   latitude   longitude  \
# 0      1                             경주시  35.855835  129.222778
# 1      1                            동네공원  37.515020  127.016480
# 2      3                 Gyeongju, Korea  35.842800  129.212000
# 3      5                      한국경마축산고등학교  35.441353  127.514898
# 4      5                        잠실여자고등학교  37.502157  127.113131
# ..   ...                             ...        ...         ...
# 939  978  해동용궁사, Haedong Yongkung Temple  35.190168  129.220248
# 941  982                          철산동어딘가  37.474937  126.868053
# 942  982         Namsangol Hanok Village  37.559167  126.993889
# 943  983                    Seoul, Korea  37.515020  127.016480
# 944  983                          백암고등학교  37.510615  126.843138
#
#                    address
# 0           경북 경주시 동천동 865
# 1          서울 서초구 잠원동 18-2
# 2          경북 경주시 노동동 99-1
# 3     전북 남원시 운봉읍 준향리 477-1
# 4          서울 송파구 송파동 99-2
# ..                     ...
# ...

# %%
df.reset_index(drop=True,inplace=True)

# %%
df1=df.copy()

# %%
df1[df1['name'].str.contains('일산 호수')]
# Out:
#      num                        name   latitude   longitude  \
# 36    40                     일산 호수공원  37.359798  126.933415
# 70    75  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 99   108  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 166  198  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 195  228  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 287  322                     일산 호수공원  37.650000  126.800000
# 362  402  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 374  411  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 401  447  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 629  703  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 777  848  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 829  910  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
# 865  945  일산 호수 공원 - Ilsan Lake Park  37.658804  126.766754
#
#                    address
# 36       경기 군포시 산본동 1126-1
# 70     경기 고양시 일산동구 장항동 906
# 99     경기 고양시 일산동구 장항동 906
# ...

# %%
mask=df1['name'].str.contains('일산 호수')
df1.loc[mask,'name']='일산 호수 공원 - Ilsan Lake Park'

# %%
df1
# Out:
#      num                            name   latitude   longitude  \
# 0      1                             경주시  35.855835  129.222778
# 1      1                            동네공원  37.515020  127.016480
# 2      3                 Gyeongju, Korea  35.842800  129.212000
# 3      5                      한국경마축산고등학교  35.441353  127.514898
# 4      5                        잠실여자고등학교  37.502157  127.113131
# ..   ...                             ...        ...         ...
# 893  978  해동용궁사, Haedong Yongkung Temple  35.190168  129.220248
# 894  982                          철산동어딘가  37.474937  126.868053
# 895  982         Namsangol Hanok Village  37.559167  126.993889
# 896  983                    Seoul, Korea  37.515020  127.016480
# 897  983                          백암고등학교  37.510615  126.843138
#
#                    address
# 0           경북 경주시 동천동 865
# 1          서울 서초구 잠원동 18-2
# 2          경북 경주시 노동동 99-1
# 3     전북 남원시 운봉읍 준향리 477-1
# 4          서울 송파구 송파동 99-2
# ..                     ...
# ...

# %%
df1.drop([i for i,x in enumerate(df1.name) if x=='Seoul, South Korea'],inplace=True)

# %%
df_pivot=df1.pivot_table(index=['name','latitude','longitude'],aggfunc='sum')
df_pivot
# Out:
#                                       num
# name           latitude  longitude
# 4호선 한대앞역       37.308299 126.852932   528
# ASAP CAFE      37.216199 127.056897     8
# Aden, Gyeongju 35.843155 129.283620   174
# Agroland       36.893600 126.628000   339
# Ansan          37.323600 126.822000  3616
# ...                                   ...
# 환상의나라 에버랜드     37.292724 127.202239    25
# 황구지천           37.120087 126.999120   806
# 황룡원            35.836529 129.290346   761
# 회사             36.345590 127.380915   832
# 회사에서           37.248722 127.102391   143
#
# [578 rows x 1 columns]

# %%
df1[df1.name.str.contains('벚꽃아래')]
# Out:
#      num  name   latitude   longitude               address
# 165  197  벚꽃아래  37.509765  127.102828         서울 송파구 잠실동 49
# 202  236  벚꽃아래  37.282631  127.044309  경기 수원시 영통구 원천동 산 5-1
# 219  249  벚꽃아래  37.408954  127.136822    경기 성남시 분당구 야탑동 519
# 304  339  벚꽃아래  37.509765  127.102828         서울 송파구 잠실동 49
# 348  389  벚꽃아래  37.408954  127.136822    경기 성남시 분당구 야탑동 519
# 409  453  벚꽃아래  37.282631  127.044309  경기 수원시 영통구 원천동 산 5-1
# 421  464  벚꽃아래  37.408954  127.136822    경기 성남시 분당구 야탑동 519
# 458  504  벚꽃아래  37.282631  127.044309  경기 수원시 영통구 원천동 산 5-1
# 528  582  벚꽃아래  37.408954  127.136822    경기 성남시 분당구 야탑동 519
# 537  595  벚꽃아래  37.509765  127.102828         서울 송파구 잠실동 49
# 599  666  벚꽃아래  37.408954  127.136822    경기 성남시 분당구 야탑동 519
# 678  752  벚꽃아래  37.509765  127.102828         서울 송파구 잠실동 49
# 770  842  벚꽃아래  37.509765  127.102828         서울 송파구 잠실동 49
# 807  884  벚꽃아래  37.509765  127.102828         서울 송파구 잠실동 49
# 843  924  벚꽃아래  37.509765  127.102828         서울 송파구 잠실동 49

# %%
list(np.sort(df1.name.unique()))
# Out:
# ['4호선 한대앞역',
#  'ASAP CAFE',
#  'Aden, Gyeongju',
#  'Agroland',
#  'Ansan',
#  'Anseong',
#  'Asan',
#  'Asiana Airlines',
#  'Boeun',
#  'Boryeong, Chungcheongnam-do',
#  "Bugil Girls' High School",
#  'Bundang',
#  'Bundang Central Park',
#  'Busan 釜山, South Korea',
#  'Busan, South Korea',
#  'Bánh Mì Phượng Hội An',
#  'Cafemoaa',
#  'Cheonan, Korea',
#  'Cheongju',
#  'Chuncheon',
#  'Chungju',
#  'Daegu',
#  'Daegu, South Korea',
#  'Daejeon',
#  'Daejeon, South Korea',
#  'Dangjin',
#  'Donghae',
#  'Dongtan, South Korea',
#  'E-World',
#  'Fleetservicecoffee',
#  'Gakwonsa Temple',
#  'Ganghwa Island',
#  'Gangjin',
#  'Gangneung',
#  'Gimcheon',
#  'Gimpo',
#  'Goesan',
#  'Gumi',
#  'Gunpo',
#  'Gunsan',
#  'Gwangju, Gyeonggi',
#  'Gwangju, South Korea',
#  'Gyeongbokgung',
#  'Gyeongju, Korea',
#  'Haeundae, Busan',
#  'Hahoe Village UNESCO World Heritage',
#  'Haus Bakery',
#  'Hilton Gyeongju / 힐튼경주',
#  'Hongseong',
#  'Hwaseong Haenggung',
#  'Icheon',
# ...

# %%
df1.value_counts('name')[:30]
# Out:
# name
# 서울숲 Seoul Forest Park         23
# 벚꽃아래                          15
# 일산 호수 공원 - Ilsan Lake Park    11
# 북서울 꿈의숲                        8
# 불광천                            7
# Incheon, Korea                 7
# Ansan                          6
# 공지천                            6
# 김천 연화지                         6
# 양재천 산책로                        6
# 설봉공원                           6
# Seoul, South Korea             5
# 여의도한강공원                        5
# 석촌호수공원                         5
# 경주                             4
# Ganghwa Island                 4
# 벚꽃엔딩                           4
# Daejeon                        4
# Daegu, South Korea             4
# 선유도공원                          4
# E-World                        4
# 봄이드아아아앙                        4
# Dangjin                        4
# Cheonan, Korea                 4
# Incheon, South Korea           4
# 서울어린이대공원                       4
# N SEOUL TOWER                  4
# 안산호수공원                         4
# ...

# %%
df.value_counts('address')[:30]
# Out:
# address
# 서울 서초구 잠원동 18-2           37
# 서울 성동구 성수동1가 685-20       25
# 경기 고양시 일산동구 장항동 906       11
# 서울 강북구 번동 90               8
# 서울 은평구 응암동 610-2           7
# 서울 송파구 잠실동 49              7
# 인천 중구 율목동 162-1            7
# 서울 강남구 도곡동 459             6
# 경기 이천시 관고동 374-1           6
# 서울 종로구 화동 2                6
# 강원 춘천시 근화동 694             6
# 경북 김천시 교동 819-2            6
# 경기 안산시 단원구 고잔동 665-1       6
# 서울 양천구 신월동 199-3           5
# 경기 성남시 분당구 야탑동 519         5
# 충남 당진시 읍내동 515-1           5
# 서울 영등포구 여의도동 87-2          5
# 서울 송파구 신천동 31              5
# 부산 연제구 연산동 1000            4
# 충남 서산시 동문동 952-1           4
# 서울 영등포구 양화동 95             4
# 경기 안산시 상록구 사동 1509         4
# 경기 고양시 일산동구 산황동 745-1      4
# 제주특별자치도 제주시 애월읍 애월리 20     4
# 경북 경주시 건천읍 신평리 886-6       4
# 대전 서구 탄방동 1478-7           4
# 서울 용산구 용산동2가 산 1-11        4
# 인천 강화군 길상면 초지리 1324-16     4
# 충남 천안시 동남구 오룡동 49-1        4
# 대구 수성구 파동 606-1            4
# dtype: int64

# %%
my_map = folium.Map(location=[36.8156690,127.7865791], zoom_start=7, tiles='OpenStreetMap')
for i in range(len(df)):
    folium.CircleMarker([df.latitude[i],df.longitude[i]],opacity=0.3,weight=10,
                        radius = 5,color='#FF0000',tooltip=str(df.name[i]+': '+df.address[i])).add_to(my_map)
my_map

# %%
my_map = folium.Map(location=[36.8156690,127.7865791], zoom_start=7, tiles='OpenStreetMap')
for i in range(len(df)):
    folium.CircleMarker([df_pivot[.latitude[i],df.longitude[i]],opacity=0.3,weight=10,
                        radius = 5,color='#FF0000',tooltip=str(df.name[i]+': '+df.address[i])).add_to(my_map)
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
googlemap_key='AIzaSyAGLRvpmuDJ5BV3grawQS9fhgyTdV0nGhQ'
gmaps = googlemaps.Client( key=googlemap_key )

# %%
data=json.loads(res1.text)['data']
print(json.loads(res1.text))
loca_table=[]
for i in range(len(data)):
    
    my_url = data[i]['permalink']
    my_headers={'User-Agent': 'Mozilla/5.0',
                'referer':'https://developers.facebook.com/',
               'cookie':'ig_did=C0BAA7E4-694B-44A9-9A2C-BA1FE38AABC9; ig_nrcb=1; mid=YGpdbwALAAFfuxOO0KCqkj6qAJB3; datr=F2VqYJ4CDzsZr1BNDb9TqFAU; shbid=8668; rur=ASH; shbts=1617585555.9594862; fbm_124024574287414=base_domain=.instagram.com; csrftoken=nYMSKBwpCKeelA9kuwwMd7b0dHXjYBU2; ds_user_id=47307588687; sessionid=47307588687:2TsdTrQbD7NIOz:10; fbsr_124024574287414=cpvHubN6iWmNb8IpILmWnHdSNA22OxZMXvPZMQTNBRo....; fbsr_124024574287414=AEALUHo2cesMQoB3FfymLn0iSr5iT0FPhpXmNOL2VTk....'}
#    res2 = rq.get(url = my_url+"?__a=1",headers = my_headers)
    res2 = rq.get(url = my_url,headers = my_headers)
    my_soup = bs4.BeautifulSoup(res2.text, 'html.parser')
    if i==2:
        #print(my_soup)
        print(json.loads(my_soup.select('script')[3].string))
    if 'contentLocation' in res2.text:
        
        loca_name=json.loads(my_soup.select('script')[3].string)['contentLocation']['name']
        a = gmaps.places(loca_name, language = 'ko')
        lat=a['results'][0]['geometry']['location']['lat']
        lng=a['results'][0]['geometry']['location']['lng']
        loca_table.append([str(loca_name),lat,lng])
print(loca_table)

# %%
my_url = first_media_url
my_headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.88 Safari/537.36'}
res = rq.get(url = my_url,headers = my_headers)      # page 1 접속.
my_soup = bs4.BeautifulSoup(res.text, 'html.parser') 
json.loads(my_soup.select('script')[3].string)['contentLocation']['name']

# %%
my_html = res.content
my_soup = bs4.BeautifulSoup(my_html, 'html.parser')     # BeautifulSoup 객체 반환. 'html.parser' 사용.

# %%
my_ul = my_soup.find('ul', id='productList')                # 단 하나의 ul 태그.
print(my_ul.prettify())

# %%
my_lis = my_ul.find_all('li')                             # 여러개의 아이템. 
for a_li in my_lis:
    print(a_li.prettify())

# %%
# 이름만 가져와 본다.
my_names = my_soup.select('ul li div.name')
my_names_list =[x.text.strip() for x in my_names]
print(my_names_list)

# %%
# 가격만 가져와 본다.
my_prices = my_soup.select('ul li em strong.price-value')
my_prices_list =[x.text.strip() for x in my_prices]
print(my_prices_list)

# %% [markdown]
# #### 가격 가져오기:

# %%
# 반복적인 부분은 함수로 처리한다.
def get_prices(my_soup):
    name_list =[]
    price_list =[]
    my_ul = my_soup.find('ul', id='productList')                # 단 하나의 ul 태그.
    if (my_ul):
        my_lis = my_ul.find_all('li')                             # 여러개의 아이템. 
        for a_li in my_lis:
            a_name = a_li.find('div', class_ = 'name')           # name 클래스의 div 가져오기.
            a_sale = a_li.find('em', class_ = 'sale')            # sale 클래스의 em 가져오기.
            if a_name and a_sale:                                # 검색이 성공적인 경우.
                a_price = a_sale.find('strong', class_ ='price-value')    # price-value 클래스의 string 태그 가져오기.
                name_list += [a_name.text.strip()]
                price_list += [float(''.join((a_price.text).split(',')))]
    return pd.DataFrame({'Product':name_list, 'Price':price_list})

# %%
# 반복적인 부분은 함수로 처리한다.
# Version 2. 
def get_prices_v2(my_soup):
    my_names = my_soup.select('ul li div.name')
    my_names_list =[x.text.strip() for x in my_names]
    my_prices = my_soup.select('ul li em strong.price-value')
    my_prices_list =[x.text.strip() for x in my_prices]
    my_prices_list_final= [float(''.join(a_price.split(','))) for a_price in my_prices_list]
    return pd.DataFrame({'Product':my_names_list, 'Price':my_prices_list_final})

# %%
for i in range(1,11):
    my_url_page = my_url + str(i)
    my_result = rq.get(my_url_page, headers=my_headers)
    if (my_result.status_code != 200):
        break
    my_html = my_result.content
    soup = bs4.BeautifulSoup(my_html, 'html.parser')     # BeautifulSoup 객체 반환. 'html.parser' 사용.
    if i == 1:
#        df = get_prices(soup)
         df = get_prices_v2(soup)
    else:
#        df = pd.concat([df, get_prices(soup)],axis=0,ignore_index=True)
        df = pd.concat([df, get_prices_v2(soup)],axis=0,ignore_index=True)

# %%
df.shape

# %%
df
